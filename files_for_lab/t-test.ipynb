# %% [markdown]
# #  T-tests and P-values
#
# In statistics, t-test is used to test if two data samples have a significant difference between their means. There are two types of t-test:
#
# * **Student's t-test** (a.k.a. independent or uncorrelated t-test). This type of t-test is to compare the samples of **two independent populations** (e.g. test scores of students in two different classes). `scipy` provides the [`ttest_ind`](https://docs.scipy.org/doc/scipy-0.15.1/reference/generated/scipy.stats.ttest_ind.html) method to conduct student's t-test.
#
# * **Paired t-test** (a.k.a. dependent or correlated t-test). This type of t-test is to compare the samples of **the same population** (e.g. scores of different tests of students in the same class). `scipy` provides the [`ttest_rel`](https://docs.scipy.org/doc/scipy-0.15.1/reference/generated/scipy.stats.ttest_rel.html) method to conduct paired t-test.
#
# Both types of t-tests return a number which is called the **p-value**. If p-value is below 0.05, we can confidently declare the null-hypothesis is rejected and the difference is significant. If p-value is between 0.05 and 0.1, we may also declare the null-hypothesis is rejected but we are not highly confident. If p-value is above 0.1 we do not reject the null-hypothesis.
#
# Read more about the t-test in [this article](http://b.link/test50) and [this Quora](http://b.link/unpaired97). Make sure you understand when to use which type of t-test.

# %%
# Import libraries
import pandas as pd
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### One tailed t-test
# In a packing plant, a machine packs cartons with jars. It is supposed that a new machine will pack faster on the average than the machine currently used. To test that hypothesis, the times it takes each machine to pack ten cartons are recorded. The results, in seconds, are shown in the tables in the file files_for_lab/ttest_machine.xlsx. Assume that there is sufficient evidence to conduct the t test, does the data provide sufficient evidence to show if one machine is better than the other?

# %% [markdown]
# #### Import dataset

# %%
# Your code here:
data=pd.read_csv(r'C:\Users\Admin\IH-Labs\lab-t-tests-p-values\files_for_lab\ttest_machine.txt')

# %%
data['New_machine']=list(map(lambda x: x.split(' ')[0],data['New_machine Old_machine']))

# %%
data['Old_machine']=list(map(lambda x: x.split(' ')[1],data['New_machine Old_machine']))

# %%
data=data.drop('New_machine Old_machine',axis=1)

# %%
for i in data.columns:
    data[i]= pd.to_numeric(data[i], errors='coerce')

# %%
# H0 = the mean time of New machine is not shorter than the old machine
# H1 = the mean time of New machine is shorter than the old machine
# significance 5%
st.ttest_ind(data['New_machine'], data['Old_machine'], equal_var=False)
print('p value (single tailed): ',st.ttest_ind(data['New_machine'], data['Old_machine'], equal_var=False)[1]/2)
# Out:
# p value (single tailed):  0.0016211247331589873

# %%
# P value is lower than 0.05 that means H0 can be rejected and there are enough evidences to prove that new machine is better than the old one.

# %% [markdown]
# #### Import dataset
#
# In this challenge we will work on the Pokemon dataset you have already used. The goal is to test whether different groups of pokemon (e.g. Legendary vs Normal, Generation 1 vs 2, single-type vs dual-type) have different stats (e.g. HP, Attack, Defense, etc.). Use pokemon.csv

# %%
# Your code here:
pokemon=pd.read_csv(r'C:\Users\Admin\IH-Labs\lab-t-tests-p-values\files_for_lab\pokemon.txt')

# %%
pokemon.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
pokemon.tail(60)
# Out:
#        #                   Name    Type 1   Type 2  Total   HP  Attack  \
# 740  672                 Skiddo     Grass      NaN    350   66      65
# 741  673                 Gogoat     Grass      NaN    531  123     100
# 742  674                Pancham  Fighting      NaN    348   67      82
# 743  675                Pangoro  Fighting     Dark    495   95     124
# 744  676                Furfrou    Normal      NaN    472   75      80
# 745  677                 Espurr   Psychic      NaN    355   62      48
# 746  678           MeowsticMale   Psychic      NaN    466   74      48
# 747  678         MeowsticFemale   Psychic      NaN    466   74      48
# 748  679                Honedge     Steel    Ghost    325   45      80
# 749  680               Doublade     Steel    Ghost    448   59     110
# 750  681   AegislashBlade Forme     Steel    Ghost    520   60     150
# 751  681  AegislashShield Forme     Steel    Ghost    520   60      50
# ...

# %%
pokemon.isna().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
#
#    Speed  Generation  Legendary
# 0     45           1      False

# %%
# Out:
#                     0
# #                   1
# Name        Bulbasaur
# Type 1          Grass
# Type 2         Poison
# Total             318
# HP                 45
# Attack             49
# Defense            49
# Sp. Atk            65
# Sp. Def            65
# Speed              45
# Generation          1
# Legendary       False

# %%
pokemon['Legendary'].value_counts()
# Out:
# False    735
# True      65
# Name: Legendary, dtype: int64

# %% [markdown]
# #### First we want to define a function with which we can test the means of a feature set of two samples.
#
# In the next cell you'll see the annotations of the Python function that explains what this function does and its arguments and returned value. This type of annotation is called **docstring** which is a convention used among Python developers. The docstring convention allows developers to write consistent tech documentations for their codes so that others can read. It also allows some websites to automatically parse the docstrings and display user-friendly documentations.
#
# Follow the specifications of the docstring and complete the function.

# %%
def t_test_features(s1, s2, features=['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Total']):
    """Test means of a feature set of two samples
    
    Args:
        s1 (dataframe): sample 1
        s2 (dataframe): sample 2
        features (list): an array of features to test
    
    Returns:
        dict: a dictionary of t-test scores for each feature where the feature name is the key and the p-value is the value
    """
    results = {}

    # Your code here
    
    return results

# %% [markdown]
# #### Using the `t_test_features` function, conduct t-test for Lengendary vs non-Legendary pokemons.
#
# *Hint: your output should look like below:*
#
# ```
# {'HP': 1.0026911708035284e-13,
#  'Attack': 2.520372449236646e-16,
#  'Defense': 4.8269984949193316e-11,
#  'Sp. Atk': 1.5514614112239812e-21,
#  'Sp. Def': 2.2949327864052826e-15,
#  'Speed': 1.049016311882451e-18,
#  'Total': 9.357954335957446e-47}
#  ```

# %%
pokemon_Legen=pokemon[pokemon['Legendary']==True][['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Total']]
pokemon_non_Legen=pokemon[pokemon['Legendary']==False][['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Total']]

# %%
pokemon_Legen.head()
# Out:
#       HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Total
# 156   90      85      100       95      125     85    580
# 157   90      90       85      125       90    100    580
# 158   90     100       90      125       85     90    580
# 162  106     110       90      154       90    130    680
# 163  106     190      100      154      100    130    780

# %%
pokemon_non_Legen.head()
# Out:
#    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Total
# 0  45      49       49       65       65     45    318
# 1  60      62       63       80       80     60    405
# 2  80      82       83      100      100     80    525
# 3  80     100      123      122      120     80    625
# 4  39      52       43       60       50     65    309

# %%
# Your code here

def t_test_features(s1, s2, features=['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Total']):
    """Test means of a feature set of two samples
    
    Args:
        s1 (dataframe): sample 1
        s2 (dataframe): sample 2
        features (list): an array of features to test
    
    Returns:
        dict: a dictionary of t-test scores for each feature where the feature name is the key and the p-value is the value
    """

    results = {}
    features1=['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Total']
    for i in features:
        results[i]=st.ttest_ind(s1[i], s2[i], equal_var=False)[1]
    
    # Your code here
    
    return results

# %%
# H0: Legendary and non-Legendary pokemons doesn't have significantly different stats on each feature?
# H1: Legendary and non-Legendary pokemons have significantly different stats on each feature?
# significance 5%
t_test_features(pokemon_Legen,pokemon_non_Legen)
# Out:
# {'HP': 1.0026911708035284e-13,
#  'Attack': 2.520372449236646e-16,
#  'Defense': 4.8269984949193316e-11,
#  'Sp. Atk': 1.5514614112239812e-21,
#  'Sp. Def': 2.2949327864052826e-15,
#  'Speed': 1.049016311882451e-18,
#  'Total': 9.357954335957446e-47}

# %% [markdown]
# #### From the test results above, what conclusion can you make? Do Legendary and non-Legendary pokemons have significantly different stats on each feature?

# %%
# Your comment here
#P value of each feature is much lower than 0.05, so that means Legendary and non Legendary pokemons have significantly different stats.

# %% [markdown]
# #### Next, conduct t-test for Generation 1 and Generation 2 pokemons.

# %%
# Your code here
pokemon_G1=pokemon[pokemon['Generation']==1]
pokemon_G2=pokemon[pokemon['Generation']==2]

# %%
pokemon_G2.shape
# Out:
# (106, 13)

# %%
# H0: Generation1 and Generation2 pokemons doesn't have significantly different stats on each feature?
# H1: Generation1 and Generation2 pokemons have significantly different stats on each feature?
# significance 5%
t_test_features(pokemon_G1,pokemon_G2)
# Out:
# {'HP': 0.14551697834219623,
#  'Attack': 0.24721958967217725,
#  'Defense': 0.5677711011725426,
#  'Sp. Atk': 0.12332165977104394,
#  'Sp. Def': 0.18829872292645752,
#  'Speed': 0.00239265937312135,
#  'Total': 0.5631377907941676}

# %% [markdown]
# #### What conclusions can you make?

# %%
# Your comment here
# apart from Speed the p values of all the other features are larger than 0.05.
# That means Generation1 and Generation2 pokemons doesn't have significantly different stats on each feature excpet speed.

# %% [markdown]
# #### Compare pokemons who have single type vs those having two types.

# %%
# Your code here
pokemon_s_type=pokemon[pokemon['Type 2'].isna()]

# %%
pokemon_s_type.shape
# Out:
# (386, 13)

# %%
pokemon_d_type=pokemon[~pokemon['Type 2'].isna()]

# %%
pokemon_d_type.shape
# Out:
# (414, 13)

# %%
t_test_features(pokemon_s_type,pokemon_d_type)
# Out:
# {'HP': 0.11314389855379421,
#  'Attack': 0.00014932578145948305,
#  'Defense': 2.7978540411514693e-08,
#  'Sp. Atk': 0.00013876216585667842,
#  'Sp. Def': 0.00010730610934512779,
#  'Speed': 0.02421703281819094,
#  'Total': 1.1157056505229961e-07}

# %% [markdown]
# #### What conclusions can you make?

# %%
# Your comment here
# except HP all the p value of each feature is lower than 0.05.
# That means Single type and two types pokemons doesn't have significantly different stats on each feature excpet HP.

# %% [markdown]
# #### Now, we want to compare whether there are significant differences of `Attack` vs `Defense`  and  `Sp. Atk` vs `Sp. Def` of all pokemons. Please write your code below.
#
# *Hint: are you comparing different populations or the same population?*

# %%
# Your code here
# H0:  there are not significant differences of Attack vs Defense and Sp. Atk vs Sp. Def of all pokemons
# H1:  there are significant differences of Attack vs Defense and Sp. Atk vs Sp. Def of all pokemons.
# significance 5%
print(st.ttest_rel(pokemon['Attack'], pokemon['Defense'])[1])
# Out:
# 1.7140303479358558e-05

# %%
st.ttest_rel(pokemon['Sp. Atk'], pokemon['Sp. Def'])[1]
# Out:
# 0.3933685997548122

# %% [markdown]
# #### What conclusions can you make?

# %%
# Your comment here
# there are significant differences of Attack and Defense but not so much different between Sp. Atk and Sp. Def of all pokemons
